# %%
import pandas as pd

# %%
NHL = "NHL_Model.csv"

# Read with Pandas
NHL_pd = pd.read_csv(NHL)
NHL_pd.head()
# Out:
#         Date      Time                 Home                 Away  Home LINE  \
# 0  10/3/2018   7:05 PM  Toronto Maple Leafs   Montreal Canadiens     -235.0
# 1  10/3/2018   7:50 PM  Washington Capitals        Boston Bruins     -105.0
# 2  10/3/2018  10:05 PM    Vancouver Canucks       Calgary Flames      123.0
# 3  10/3/2018  10:35 PM      San Jose Sharks        Anaheim Ducks     -179.0
# 4  10/4/2018   7:05 PM  Pittsburgh Penguins  Washington Capitals     -162.0
#
#    Away LINE Home Win Away Win                      Pick Pick value  \
# 0      210.0   71.04%   28.96%  Toronto Maple Leafs -235      1.34%
# 1     -105.0   49.85%   50.15%        Boston Bruins -105      2.35%
# 2     -136.0   41.55%   58.45%       Calgary Flames -136      2.55%
# 3      161.0   66.78%   33.22%      San Jose Sharks -179      4.28%
# 4      146.0   65.12%   34.88%  Pittsburgh Penguins -162      4.02%
#
#       ...      Unnamed: 26  MP Home MP Away.1 MP Home.1 MP Away Edge  \
# ...

# %%
NHL_pd.columns
# Out:
# Index(['Date', 'Time', 'Home', 'Away', 'Home LINE', 'Away LINE', 'Home Win',
#        'Away Win', 'Pick', 'Pick value', 'BH Away', 'BH Home', 'Away%',
#        'Home%', 'Away Team', 'Away Edge', 'Home Team', 'Home Edge', 'Risk',
#        'Result', 'Result Unit', 'Away Team.1', 'Home Team.1', 'MP Away',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'MP Home', 'MP Away.1',
#        'MP Home.1', 'MP Away Edge', 'MP Home edge', 'Team', 'Risk.1',
#        'Result.1', 'Unnamed: 35'],
#       dtype='object')

# %%
MLB = ["HOU","NYA","BOS"]

# %%
for teams in MLB:
    print(f"https://legacy.baseballprospectus.com/fantasy/dc/index.php?tm=TBA {teams}")
# Out:
# https://legacy.baseballprospectus.com/fantasy/dc/index.php?tm=TBA HOU
# https://legacy.baseballprospectus.com/fantasy/dc/index.php?tm=TBA NYA
# https://legacy.baseballprospectus.com/fantasy/dc/index.php?tm=TBA BOS
